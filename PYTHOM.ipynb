# %% [markdown]
# <a href="https://colab.research.google.com/github/marjoryjesus/python/blob/main/PYTHOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3900916270.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3 figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
#       4 figurinhas_joao = 2 * figurinhas_amigo
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %% [markdown]
# **aula 4**

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# **aula 5**

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} // {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)

# %% [markdown]
# **aula 6**

# %%
print("olá, sou seu assistente virtual")
nome = input ("digite seu nome: ")
print(f"olá{nome}, em que posso ajudar?")
resposta = input("Você deseja falar sobre Python, javacript ou matemática: ").lower()
if resposta =="python":
  print(f"Ótimo, {nome},vamos falar sobre Python. \n Python é uma linguagem de programação simples e poderosa, usada para desenvolvimento web, análise de dados, inteligência artificial e muito mais.")
elif resposta == "javascript":
  print(f"ótimo,{nome},vamos falar sobre Javascript. \n JavaScript é uma linguagem usada para criar interatividade e dinamismo em sites.JavaScript é uma linguagem usada para criar interatividade e dinamismo em sites.")
elif resposta == "javascript":
  print(f"Otimo, {nome}, vamos falar sobre matemática. \n Matemática é a ciência que estuda números, formas, estruturas, e padrões, sendo essencial para entender e resolver problemas em diversas áreas, como física, economia e engenharia.")
else:
    print(f" Que pena, {nome}, não sei falar dess assunto")
# Out:
# olá, sou seu assistente virtual

# %% [markdown]
# **aula 3**

# %% [markdown]
# #**AULA** 1  🧚 💕 😉 ![image.png](data:image/png;base64,...)

# %%
ano = "IX"
print(ano, "competição de programação da Start")
# Out:
# IX competição de programação da Start

# %% [markdown]
# ##**AULA 2 ** ♥ 📸 ⏱

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_ana + pontos_rodrigo
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do Ana são 46
# Os pontos totais de Ana e Rodrigo são 70
